# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
dataset_url = 'https://www.openml.org/data/get_csv/16826755/phpMYEkMl'

data = pd.read_csv(dataset_url)
data.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#       age  sibsp  parch  ticket      fare    cabin embarked boat body  \
# 0      29      0      0   24160  211.3375       B5        S    2    ?
# 1  0.9167      1      2  113781    151.55  C22 C26        S   11    ?
# 2       2      1      2  113781    151.55  C22 C26        S    ?    ?
# 3      30      1      2  113781    151.55  C22 C26        S    ?  135
# 4      25      1      2  113781    151.55  C22 C26        S    ?    ?
#
#                          home.dest
# 0                     St Louis, MO
# 1  Montreal, PQ / Chesterville, ON
# 2  Montreal, PQ / Chesterville, ON
# 3  Montreal, PQ / Chesterville, ON
# 4  Montreal, PQ / Chesterville, ON

# %%
data.to_csv('raw.csv')

# %%
y = data['survived']
X = data.drop('survived', axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=0.2)

# %%
df_train = pd.concat([X_train, y_train], axis=1)
df_train.head()
# Out:
#      pclass                        name     sex age  sibsp  parch      ticket  \
# 326       2  Andrew, Mr. Edgardo Samuel    male  18      0      0      231945
# 22        1       Behr, Mr. Karl Howell    male  26      0      0      111369
# 464       2  Jenkin, Mr. Stephen Curnow    male  32      0      0  C.A. 33111
# 957       3     Lefebre, Miss. Mathilde  female   ?      3      1        4133
# 271       1  Snyder, Mr. John Pillsbury    male  24      1      0       21228
#
#         fare cabin embarked boat body  \
# 326     11.5     ?        S    ?    ?
# 22        30  C148        C    5    ?
# 464     10.5     ?        S    ?    ?
# 957  25.4667     ?        S    ?    ?
# 271  82.2667   B45        S    7    ?
#
#                                     home.dest  survived
# 326  Buenos Aires, Argentina / New Jersey, NJ         0
# 22                               New York, NY         1
# 464          St Ives, Cornwall / Houghton, MI         0
# 957                                         ?         0
# 271                           Minneapolis, MN         1

# %%
df_train.to_csv('train.csv')

# %%
X_test.head()
# Out:
#       pclass                                         name     sex age  sibsp  \
# 367        2                   Chapman, Mr. Charles Henry    male  52      0
# 250        1                   Ryerson, Miss. Emily Borie  female  18      2
# 230        1                        Perreault, Miss. Anne  female  30      0
# 1100       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29      0
# 261        1             Silverthorne, Mr. Spencer Victor    male  35      0
#
#       parch    ticket     fare            cabin embarked boat body  \
# 367       0    248731     13.5                ?        S    ?  130
# 250       2  PC 17608  262.375  B57 B59 B63 B66        C    4    ?
# 230       0     12749     93.5              B73        S    3    ?
# 1100      4    349909   21.075                ?        S    ?  206
# 261       0  PC 17475  26.2875              E24        S    5    ?
#
#                             home.dest
# 367                         Bronx, NY
# 250   Haverford, PA / Cooperstown, NY
# 230                                 ?
# 1100                                ?
# 261                      St Louis, MO

# %%
X_test.to_csv('test.csv')
